# %%
import numpy as np
import pandas as pd
import math

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split

from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor, export_graphviz

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, r2_score, DistanceMetric, \
    mean_squared_error,mean_absolute_error, mean_absolute_percentage_error

import graphviz

# %% [markdown]
# # Dados utilizados

# %% [markdown]
# # Classificação

# %% [markdown]
# # Carregando os dados

# %%
Train_Data = pd.read_csv("../../Datasets/heart.csv")
Train_Data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# ## Descrição das colunas

# %% [markdown]
# 1. __Age__ is the age of candidate.
# 2. __Sex__ has numeric values. 1 denotes male and 0 denotes female.
# 3. __Chest Pain__ pain has values between 0-3. The types of angina that are described in the research paper. The higher the number, the lesser are the odds of heart attack.
# 4. __Resting blood pressure__ is normal pressure with no exercise.
# 5. __Cholesterol__ means the blockage for blood supply in the blood vessels.
# 6. __Fasting Blood Pressure__ is blood sugar taken after a long gap between a meal and the test. Typically, it's taken before any meal in the morning. 1 denotes > 120 mg/dl
# 7. __Rest ECG (electrocardiographic) results__ means ECG values taken while person is on rest which means no exercise and normal functioning of heart is happening. Values 0,1,2.
# 8. __The Maximum Heart Rate achieved__.
# 9. __Exercise induced angina__ is chest pain while exercising or doing any physical activity. 1 denotes presence and 0 denotes absence.
# 10. __Oldpeak__ = ST Depression induced by exercise relative to rest. ST Depression is the difference between value of ECG at rest and after exercise.
# 11. __ST Slope__ is the tangent to the depression value.
# 12. __The number of major blood vessels (0-3) supplying blood to heart blocked__.
# 13. __The Types of thalassemia__.
# 14. __Heart attack prediction__ where 1 denotes Heart attack occured and 0 where it din't take occur.

# %%
Train_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# # Checar se as classes estão balanceadas

# %%
Train_Data['target'].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %% [markdown]
# # Checar se existem dados duplicados

# %%
print("Duplicated values: ", Train_Data.duplicated().sum())
duplicate = Train_Data[Train_Data.duplicated()]
duplicate
# Out:
# Duplicated values:  1
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 164   38    1   2       138   175    0        1      173      0      0.0
#
#      slope  ca  thal  target
# 164      2   4     2       1

# %% [markdown]
# ### Remover dados duplicados, deixando apenas a primeira ocorrência

# %%
Train_Data.drop_duplicates(keep='first',inplace=True) 
Train_Data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [302 rows x 14 columns]

# %% [markdown]
# # Checar se existem dados faltantes

# %%
print("Missing values: ", Train_Data.isnull().sum().sum())
# Out:
# Missing values:  0

# %% [markdown]
# # Checar se existem correlações entre os atributos e a saída

# %%
corr = Train_Data.corr()
corr.style.background_gradient(cmap = 'viridis')
# Out:
# <style type="text/css">
# #T_601ab_row0_col0, #T_601ab_row1_col1, #T_601ab_row2_col2, #T_601ab_row3_col3, #T_601ab_row4_col4, #T_601ab_row5_col5, #T_601ab_row6_col6, #T_601ab_row7_col7, #T_601ab_row8_col8, #T_601ab_row9_col9, #T_601ab_row10_col10, #T_601ab_row11_col11, #T_601ab_row12_col12, #T_601ab_row13_col13 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_601ab_row0_col1 {
#   background-color: #46337f;
#   color: #f1f1f1;
# }
# #T_601ab_row0_col2, #T_601ab_row2_col0, #T_601ab_row4_col3, #T_601ab_row11_col4 {
#   background-color: #3d4e8a;
#   color: #f1f1f1;
# }
# #T_601ab_row0_col3, #T_601ab_row11_col12 {
#   background-color: #2c718e;
#   color: #f1f1f1;
# }
# #T_601ab_row0_col4 {
#   background-color: #30698e;
#   color: #f1f1f1;
# }
# #T_601ab_row0_col5, #T_601ab_row7_col1, #T_601ab_row7_col12, #T_601ab_row8_col3 {
#   background-color: #423f85;
#   color: #f1f1f1;
# }
# #T_601ab_row0_col6 {
#   background-color: #470d60;
#   color: #f1f1f1;
# }
# #T_601ab_row0_col7, #T_601ab_row1_col4, #T_601ab_row4_col6, #T_601ab_row6_col5, #T_601ab_row7_col0, #T_601ab_row8_col2, #T_601ab_row8_col13, #T_601ab_row9_col10, #T_601ab_row10_col9, #T_601ab_row13_col1, #T_601ab_row13_col3, #T_601ab_row13_col8, #T_601ab_row13_col11, #T_601ab_row13_col12 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_601ab_row0_col8, #T_601ab_row1_col11, #T_601ab_row5_col0, #T_601ab_row5_col9 {
#   background-color: #2d718e;
#   color: #f1f1f1;
# }
# #T_601ab_row0_col9, #T_601ab_row11_col0, #T_601ab_row12_col9 {
#   background-color: #21908d;
#   color: #f1f1f1;
# }
# #T_601ab_row0_col10 {
#   background-color: #3a548c;
#   color: #f1f1f1;
# }
# #T_601ab_row0_col11 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_601ab_row0_col12, #T_601ab_row3_col12 {
#   background-color: #34608d;
#   color: #f1f1f1;
# }
# #T_601ab_row0_col13, #T_601ab_row2_col11, #T_601ab_row7_col9 {
#   background-color: #463480;
#   color: #f1f1f1;
# }
# #T_601ab_row1_col0, #T_601ab_row8_col4, #T_601ab_row12_col7 {
#   background-color: #3f4889;
#   color: #f1f1f1;
# }
# #T_601ab_row1_col2, #T_601ab_row12_col4 {
#   background-color: #3c508b;
#   color: #f1f1f1;
# }
# #T_601ab_row1_col3, #T_601ab_row1_col6 {
#   background-color: #481c6e;
#   color: #f1f1f1;
# }
# #T_601ab_row1_col5, #T_601ab_row11_col7, #T_601ab_row12_col6 {
#   background-color: #472a7a;
#   color: #f1f1f1;
# }
# #T_601ab_row1_col7, #T_601ab_row3_col7, #T_601ab_row4_col13, #T_601ab_row6_col12, #T_601ab_row13_col6 {
#   background-color: #3b518b;
#   color: #f1f1f1;
# }
# #T_601ab_row1_col8, #T_601ab_row12_col11 {
#   background-color: #29798e;
#   color: #f1f1f1;
# }
# #T_601ab_row1_col9 {
#   background-color: #277f8e;
#   color: #f1f1f1;
# }
# #T_601ab_row1_col10 {
#   background-color: #2f6b8e;
#   color: #f1f1f1;
# }
# #T_601ab_row1_col12, #T_601ab_row9_col12 {
#   background-color: #297b8e;
#   color: #f1f1f1;
# }
# #T_601ab_row1_col13 {
#   background-color: #482677;
#   color: #f1f1f1;
# }
# #T_601ab_row2_col1, #T_601ab_row12_col3 {
#   background-color: #433e85;
#   color: #f1f1f1;
# }
# #T_601ab_row2_col3 {
#   background-color: #443a83;
#   color: #f1f1f1;
# }
# #T_601ab_row2_col4 {
#   background-color: #482576;
#   color: #f1f1f1;
# }
# #T_601ab_row2_col5, #T_601ab_row2_col6, #T_601ab_row7_col6, #T_601ab_row10_col0, #T_601ab_row12_col2 {
#   background-color: #443983;
#   color: #f1f1f1;
# }
# #T_601ab_row2_col7, #T_601ab_row7_col2 {
#   background-color: #218f8d;
#   color: #f1f1f1;
# }
# #T_601ab_row2_col8, #T_601ab_row3_col6 {
#   background-color: #460b5e;
#   color: #f1f1f1;
# }
# #T_601ab_row2_col9 {
#   background-color: #38588c;
#   color: #f1f1f1;
# }
# #T_601ab_row2_col10 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_601ab_row2_col12 {
#   background-color: #472f7d;
#   color: #f1f1f1;
# }
# #T_601ab_row2_col13 {
#   background-color: #23a983;
#   color: #f1f1f1;
# }
# #T_601ab_row3_col0 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_601ab_row3_col1, #T_601ab_row9_col2, #T_601ab_row10_col12 {
#   background-color: #433d84;
#   color: #f1f1f1;
# }
# #T_601ab_row3_col2, #T_601ab_row6_col7 {
#   background-color: #33638d;
#   color: #f1f1f1;
# }
# #T_601ab_row3_col4 {
#   background-color: #39568c;
#   color: #f1f1f1;
# }
# #T_601ab_row3_col5 {
#   background-color: #3c4f8a;
#   color: #f1f1f1;
# }
# #T_601ab_row3_col8, #T_601ab_row4_col8, #T_601ab_row5_col2, #T_601ab_row8_col0 {
#   background-color: #2f6c8e;
#   color: #f1f1f1;
# }
# #T_601ab_row3_col9 {
#   background-color: #218e8d;
#   color: #f1f1f1;
# }
# #T_601ab_row3_col10 {
#   background-color: #365c8d;
#   color: #f1f1f1;
# }
# #T_601ab_row3_col11 {
#   background-color: #2e6f8e;
#   color: #f1f1f1;
# }
# #T_601ab_row3_col13 {
#   background-color: #414487;
#   color: #f1f1f1;
# }
# #T_601ab_row4_col0, #T_601ab_row9_col0 {
#   background-color: #27808e;
#   color: #f1f1f1;
# }
# #T_601ab_row4_col1, #T_601ab_row7_col5, #T_601ab_row8_col6 {
#   background-color: #481a6c;
#   color: #f1f1f1;
# }
# #T_601ab_row4_col2 {
#   background-color: #3e4c8a;
#   color: #f1f1f1;
# }
# #T_601ab_row4_col5 {
#   background-color: #482071;
#   color: #f1f1f1;
# }
# #T_601ab_row4_col7, #T_601ab_row5_col7 {
#   background-color: #375a8c;
#   color: #f1f1f1;
# }
# #T_601ab_row4_col9, #T_601ab_row6_col13 {
#   background-color: #2a778e;
#   color: #f1f1f1;
# }
# #T_601ab_row4_col10, #T_601ab_row10_col2 {
#   background-color: #2d708e;
#   color: #f1f1f1;
# }
# #T_601ab_row4_col11 {
#   background-color: #2e6d8e;
#   color: #f1f1f1;
# }
# #T_601ab_row4_col12 {
#   background-color: #31668e;
#   color: #f1f1f1;
# }
# #T_601ab_row5_col1, #T_601ab_row6_col8 {
#   background-color: #3a538b;
#   color: #f1f1f1;
# }
# #T_601ab_row5_col3, #T_601ab_row5_col13 {
#   background-color: #375b8d;
#   color: #f1f1f1;
# }
# #T_601ab_row5_col4, #T_601ab_row6_col1 {
#   background-color: #443b84;
#   color: #f1f1f1;
# }
# #T_601ab_row5_col6, #T_601ab_row11_col6 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# #T_601ab_row5_col8 {
#   background-color: #32658e;
#   color: #f1f1f1;
# }
# #T_601ab_row5_col10, #T_601ab_row6_col9, #T_601ab_row12_col0 {
#   background-color: #31678e;
#   color: #f1f1f1;
# }
# #T_601ab_row5_col11, #T_601ab_row11_col8 {
#   background-color: #2a768e;
#   color: #f1f1f1;
# }
# #T_601ab_row5_col12, #T_601ab_row6_col11 {
#   background-color: #3d4d8a;
#   color: #f1f1f1;
# }
# #T_601ab_row6_col0, #T_601ab_row8_col10, #T_601ab_row9_col4 {
#   background-color: #404588;
#   color: #f1f1f1;
# }
# #T_601ab_row6_col2, #T_601ab_row11_col1 {
#   background-color: #33628d;
#   color: #f1f1f1;
# }
# #T_601ab_row6_col3 {
#   background-color: #460a5d;
#   color: #f1f1f1;
# }
# #T_601ab_row6_col4, #T_601ab_row7_col8 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_601ab_row6_col10 {
#   background-color: #277e8e;
#   color: #f1f1f1;
# }
# #T_601ab_row7_col3 {
#   background-color: #481f70;
#   color: #f1f1f1;
# }
# #T_601ab_row7_col4 {
#   background-color: #453781;
#   color: #f1f1f1;
# }
# #T_601ab_row7_col10 {
#   background-color: #25ab82;
#   color: #f1f1f1;
# }
# #T_601ab_row7_col11, #T_601ab_row10_col8 {
#   background-color: #472d7b;
#   color: #f1f1f1;
# }
# #T_601ab_row7_col13 {
#   background-color: #22a785;
#   color: #f1f1f1;
# }
# #T_601ab_row8_col1 {
#   background-color: #31688e;
#   color: #f1f1f1;
# }
# #T_601ab_row8_col5 {
#   background-color: #482475;
#   color: #f1f1f1;
# }
# #T_601ab_row8_col7 {
#   background-color: #450559;
#   color: #f1f1f1;
# }
# #T_601ab_row8_col9 {
#   background-color: #1e9c89;
#   color: #f1f1f1;
# }
# #T_601ab_row8_col11 {
#   background-color: #2c738e;
#   color: #f1f1f1;
# }
# #T_601ab_row8_col12 {
#   background-color: #297a8e;
#   color: #f1f1f1;
# }
# #T_601ab_row9_col1, #T_601ab_row9_col3, #T_601ab_row12_col10 {
#   background-color: #355f8d;
#   color: #f1f1f1;
# }
# #T_601ab_row9_col5, #T_601ab_row9_col6 {
#   background-color: #481d6f;
#   color: #f1f1f1;
# }
# #T_601ab_row9_col7 {
#   background-color: #470e61;
#   color: #f1f1f1;
# }
# #T_601ab_row9_col8 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_601ab_row9_col11 {
#   background-color: #24868e;
#   color: #f1f1f1;
# }
# #T_601ab_row9_col13 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_601ab_row10_col1 {
#   background-color: #424186;
#   color: #f1f1f1;
# }
# #T_601ab_row10_col3, #T_601ab_row10_col5 {
#   background-color: #46085c;
#   color: #f1f1f1;
# }
# #T_601ab_row10_col4 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
# #T_601ab_row10_col6, #T_601ab_row11_col5 {
#   background-color: #404688;
#   color: #f1f1f1;
# }

# %% [markdown]
# ## Dividir atributos e saída

# %%
X=Train_Data[Train_Data.columns[Train_Data.columns!='target']]
X.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal
# 0   0     1
# 1   0     2
# 2   0     2
# 3   0     2
# 4   0     2

# %%
Y=Train_Data['target']

# %% [markdown]
# # Separar treinamento e teste

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ## Resultados a serem imprimidos

# %%
def results(y_test,y_pred):
    results = confusion_matrix(y_test, y_pred)
    print ('Confusion Matrix :')
    print(results)
    accuracy = accuracy_score(y_test, y_pred)
    print("Accuracy: %.2f%%" % (accuracy * 100.0))
    print ('Report : ')
    print (classification_report(y_test, y_pred))

# %% [markdown]
# # Árvore de decisão

# %% [markdown]
# ## Classificação

# %%
def computeClassificationDecisionTree(X_train, X_test, y_train, y_test, printResults):
    arvore_classificacao = DecisionTreeClassifier()
    arvore_classificacao.fit(X_train, y_train)
    y_pred = arvore_classificacao.predict(X_test)
    if printResults:
        results(y_test, y_pred)
    return y_pred, arvore_classificacao

# %%
y_pred, arvore_classificacao = computeClassificationDecisionTree(X_train, X_test, y_train, y_test, True)
# Out:
# Confusion Matrix :
# [[22  5]
#  [ 8 26]]
# Accuracy: 78.69%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.73      0.81      0.77        27
#            1       0.84      0.76      0.80        34
#
#     accuracy                           0.79        61
#    macro avg       0.79      0.79      0.79        61
# weighted avg       0.79      0.79      0.79        61

# %% [markdown]
# ## Plotando as regras criadas

# %%
dot_data = export_graphviz(arvore_classificacao, out_file=None)

# %%
graph = graphviz.Source(dot_data)
graph.render("heart")
# Out:
# 'heart.pdf'

# %%
X_train.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal'],
#       dtype='object')

# %%
dot_data = export_graphviz(arvore_classificacao, out_file=None, 
                      feature_names=X_train.columns,  
                      class_names=['não infarto','infarto'],  
                      filled=True, rounded=True,  
                      special_characters=True)  
graph = graphviz.Source(dot_data)

# %%
graph.render("heart2")
# Out:
# 'heart2.pdf'

# %% [markdown]
# ## Regressão

# %%
df = pd.read_csv('../../Datasets/diamonds.csv', sep = ",", low_memory=False)
#removendo os ids
df = df.drop(df.columns[0], axis=1)
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# **price**: price in US dollars (\$326--\$18,823)
#
# **carat**: weight of the diamond (0.2--5.01)
#
# **cut**: quality of the cut (Fair, Good, Very Good, Premium, Ideal)
#
# **color**: diamond colour, from J (worst) to D (best)
#
# **clarity**: a measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
#
# **x**: length in mm (0--10.74)
#
# **y**: width in mm (0--58.9)
#
# **z**: depth in mm (0--31.8)
#
# **depth**: total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79)
#
# **table**: width of top of diamond relative to widest point (43--95)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %% [markdown]
# ## One Hot Encoding
#
# Transformar atributos nominais em numéricos

# %%
le = LabelEncoder()
for column in df.select_dtypes('object'):
    df[column] = le.fit_transform(df[column])
        
df.head()
# Out:
#    carat  cut  color  clarity  depth  table  price     x     y     z
# 0   0.23    2      1        3   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    3      1        2   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23    1      1        4   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    3      5        5   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31    1      6        3   63.3   58.0    335  4.34  4.35  2.75

# %%
print("Missing values: ", df.isnull().sum())
# Out:
# Missing values:  carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %% [markdown]
# ### Checando se existem dados duplicados, preservando a primeira ocorrência:

# %%
print("Duplicated values: ", df.duplicated().sum())

#Checando quais são as linhas duplicadas
duplicateRowsDF = df[df.duplicated()]
#duplicateRowsDF

#Removendo as linhas duplicadas, deixando apenas a primeira ocorrência
df.drop_duplicates(keep='first',inplace=True) 
#df
# Out:
# Duplicated values:  146

# %%
corr = df.corr()
corr.style.background_gradient(cmap = 'viridis')
# Out:
# <style type="text/css">
# #T_df2bc_row0_col0, #T_df2bc_row1_col1, #T_df2bc_row2_col2, #T_df2bc_row3_col3, #T_df2bc_row4_col4, #T_df2bc_row5_col5, #T_df2bc_row6_col6, #T_df2bc_row7_col7, #T_df2bc_row8_col8, #T_df2bc_row9_col9 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_df2bc_row0_col1 {
#   background-color: #433d84;
#   color: #f1f1f1;
# }
# #T_df2bc_row0_col2 {
#   background-color: #33628d;
#   color: #f1f1f1;
# }
# #T_df2bc_row0_col3 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_df2bc_row0_col4 {
#   background-color: #3b528b;
#   color: #f1f1f1;
# }
# #T_df2bc_row0_col5, #T_df2bc_row8_col5 {
#   background-color: #2d718e;
#   color: #f1f1f1;
# }
# #T_df2bc_row0_col6 {
#   background-color: #d0e11c;
#   color: #000000;
# }
# #T_df2bc_row0_col7, #T_df2bc_row7_col0, #T_df2bc_row7_col8, #T_df2bc_row8_col7 {
#   background-color: #f1e51d;
#   color: #000000;
# }
# #T_df2bc_row0_col8, #T_df2bc_row8_col0, #T_df2bc_row8_col9, #T_df2bc_row9_col8 {
#   background-color: #e5e419;
#   color: #000000;
# }
# #T_df2bc_row0_col9, #T_df2bc_row9_col0 {
#   background-color: #e7e419;
#   color: #000000;
# }
# #T_df2bc_row1_col0, #T_df2bc_row3_col4 {
#   background-color: #424086;
#   color: #f1f1f1;
# }
# #T_df2bc_row1_col2 {
#   background-color: #460b5e;
#   color: #f1f1f1;
# }
# #T_df2bc_row1_col3, #T_df2bc_row8_col4 {
#   background-color: #404588;
#   color: #f1f1f1;
# }
# #T_df2bc_row1_col4 {
#   background-color: #481d6f;
#   color: #f1f1f1;
# }
# #T_df2bc_row1_col5, #T_df2bc_row9_col5 {
#   background-color: #2f6b8e;
#   color: #f1f1f1;
# }
# #T_df2bc_row1_col6 {
#   background-color: #482576;
#   color: #f1f1f1;
# }
# #T_df2bc_row1_col7, #T_df2bc_row1_col8, #T_df2bc_row4_col0 {
#   background-color: #414487;
#   color: #f1f1f1;
# }
# #T_df2bc_row1_col9, #T_df2bc_row3_col1, #T_df2bc_row5_col6, #T_df2bc_row8_col1 {
#   background-color: #423f85;
#   color: #f1f1f1;
# }
# #T_df2bc_row2_col0 {
#   background-color: #287c8e;
#   color: #f1f1f1;
# }
# #T_df2bc_row2_col1, #T_df2bc_row2_col3, #T_df2bc_row3_col5, #T_df2bc_row4_col7, #T_df2bc_row9_col1 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
# #T_df2bc_row2_col4 {
#   background-color: #39568c;
#   color: #f1f1f1;
# }
# #T_df2bc_row2_col5 {
#   background-color: #3b518b;
#   color: #f1f1f1;
# }
# #T_df2bc_row2_col6 {
#   background-color: #3e4c8a;
#   color: #f1f1f1;
# }
# #T_df2bc_row2_col7 {
#   background-color: #29798e;
#   color: #f1f1f1;
# }
# #T_df2bc_row2_col8 {
#   background-color: #2a778e;
#   color: #f1f1f1;
# }
# #T_df2bc_row2_col9 {
#   background-color: #2a788e;
#   color: #f1f1f1;
# }
# #T_df2bc_row3_col0, #T_df2bc_row3_col2, #T_df2bc_row3_col6, #T_df2bc_row3_col7, #T_df2bc_row3_col8, #T_df2bc_row3_col9, #T_df2bc_row4_col1, #T_df2bc_row4_col5, #T_df2bc_row5_col4, #T_df2bc_row7_col3, #T_df2bc_row9_col3 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_df2bc_row4_col2 {
#   background-color: #481b6d;
#   color: #f1f1f1;
# }
# #T_df2bc_row4_col3 {
#   background-color: #46327e;
#   color: #f1f1f1;
# }
# #T_df2bc_row4_col6 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# #T_df2bc_row4_col8 {
#   background-color: #453581;
#   color: #f1f1f1;
# }
# #T_df2bc_row4_col9 {
#   background-color: #3a548c;
#   color: #f1f1f1;
# }
# #T_df2bc_row5_col0, #T_df2bc_row6_col5 {
#   background-color: #31668e;
#   color: #f1f1f1;
# }
# #T_df2bc_row5_col1, #T_df2bc_row9_col2 {
#   background-color: #365c8d;
#   color: #f1f1f1;
# }
# #T_df2bc_row5_col2 {
#   background-color: #481467;
#   color: #f1f1f1;
# }
# #T_df2bc_row5_col3 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_df2bc_row5_col7 {
#   background-color: #306a8e;
#   color: #f1f1f1;
# }
# #T_df2bc_row5_col8 {
#   background-color: #31678e;
#   color: #f1f1f1;
# }
# #T_df2bc_row5_col9 {
#   background-color: #34618d;
#   color: #f1f1f1;
# }
# #T_df2bc_row6_col0 {
#   background-color: #d5e21a;
#   color: #000000;
# }
# #T_df2bc_row6_col1 {
#   background-color: #414287;
#   color: #f1f1f1;
# }
# #T_df2bc_row6_col2 {
#   background-color: #424186;
#   color: #f1f1f1;
# }
# #T_df2bc_row6_col3 {
#   background-color: #472d7b;
#   color: #f1f1f1;
# }
# #T_df2bc_row6_col4 {
#   background-color: #3e4989;
#   color: #f1f1f1;
# }
# #T_df2bc_row6_col7 {
#   background-color: #c0df25;
#   color: #000000;
# }
# #T_df2bc_row6_col8 {
#   background-color: #b5de2b;
#   color: #000000;
# }
# #T_df2bc_row6_col9 {
#   background-color: #b2dd2d;
#   color: #000000;
# }
# #T_df2bc_row7_col1 {
#   background-color: #433e85;
#   color: #f1f1f1;
# }
# #T_df2bc_row7_col2 {
#   background-color: #365d8d;
#   color: #f1f1f1;
# }
# #T_df2bc_row7_col4 {
#   background-color: #404688;
#   color: #f1f1f1;
# }
# #T_df2bc_row7_col5 {
#   background-color: #2c738e;
#   color: #f1f1f1;
# }
# #T_df2bc_row7_col6 {
#   background-color: #b8de29;
#   color: #000000;
# }
# #T_df2bc_row7_col9, #T_df2bc_row9_col7 {
#   background-color: #efe51c;
#   color: #000000;
# }
# #T_df2bc_row8_col2 {
#   background-color: #375b8d;
#   color: #f1f1f1;
# }
# #T_df2bc_row8_col3 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_df2bc_row8_col6 {
#   background-color: #aadc32;
#   color: #000000;
# }
# #T_df2bc_row9_col4 {
#   background-color: #34608d;
#   color: #f1f1f1;
# }
# #T_df2bc_row9_col6 {
#   background-color: #a8db34;
#   color: #000000;
# }
# </style>
# <table id="T_df2bc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_df2bc_level0_col0" class="col_heading level0 col0" >carat</th>
#       <th id="T_df2bc_level0_col1" class="col_heading level0 col1" >cut</th>
#       <th id="T_df2bc_level0_col2" class="col_heading level0 col2" >color</th>
#       <th id="T_df2bc_level0_col3" class="col_heading level0 col3" >clarity</th>
#       <th id="T_df2bc_level0_col4" class="col_heading level0 col4" >depth</th>
#       <th id="T_df2bc_level0_col5" class="col_heading level0 col5" >table</th>
#       <th id="T_df2bc_level0_col6" class="col_heading level0 col6" >price</th>
#       <th id="T_df2bc_level0_col7" class="col_heading level0 col7" >x</th>
#       <th id="T_df2bc_level0_col8" class="col_heading level0 col8" >y</th>
#       <th id="T_df2bc_level0_col9" class="col_heading level0 col9" >z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df2bc_level0_row0" class="row_heading level0 row0" >carat</th>
#       <td id="T_df2bc_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_df2bc_row0_col1" class="data row0 col1" >0.017785</td>
#       <td id="T_df2bc_row0_col2" class="data row0 col2" >0.291019</td>
#       <td id="T_df2bc_row0_col3" class="data row0 col3" >-0.214068</td>
#       <td id="T_df2bc_row0_col4" class="data row0 col4" >0.027861</td>
#       <td id="T_df2bc_row0_col5" class="data row0 col5" >0.181091</td>
#       <td id="T_df2bc_row0_col6" class="data row0 col6" >0.921548</td>
#       <td id="T_df2bc_row0_col7" class="data row0 col7" >0.975380</td>
#       <td id="T_df2bc_row0_col8" class="data row0 col8" >0.951908</td>
#       <td id="T_df2bc_row0_col9" class="data row0 col9" >0.953542</td>
#     </tr>
#     <tr>
#       <th id="T_df2bc_level0_row1" class="row_heading level0 row1" >cut</th>
#       <td id="T_df2bc_row1_col0" class="data row1 col0" >0.017785</td>
#       <td id="T_df2bc_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_df2bc_row1_col2" class="data row1 col2" >0.000393</td>
#       <td id="T_df2bc_row1_col3" class="data row1 col3" >0.028141</td>
#       <td id="T_df2bc_row1_col4" class="data row1 col4" >-0.193184</td>
#       <td id="T_df2bc_row1_col5" class="data row1 col5" >0.150366</td>
#       <td id="T_df2bc_row1_col6" class="data row1 col6" >0.040196</td>
#       <td id="T_df2bc_row1_col7" class="data row1 col7" >0.022592</td>
#       <td id="T_df2bc_row1_col8" class="data row1 col8" >0.027805</td>
#       <td id="T_df2bc_row1_col9" class="data row1 col9" >0.002442</td>
#     </tr>
#     <tr>
#       <th id="T_df2bc_level0_row2" class="row_heading level0 row2" >color</th>
#       <td id="T_df2bc_row2_col0" class="data row2 col0" >0.291019</td>
#       <td id="T_df2bc_row2_col1" class="data row2 col1" >0.000393</td>
#       <td id="T_df2bc_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_df2bc_row2_col3" class="data row2 col3" >-0.028002</td>
#       <td id="T_df2bc_row2_col4" class="data row2 col4" >0.047572</td>
#       <td id="T_df2bc_row2_col5" class="data row2 col5" >0.026102</td>
#       <td id="T_df2bc_row2_col6" class="dat

# %% [markdown]
# ### Separando o alvo (preço) dos atributos

# %%
target = pd.DataFrame(df, columns=["price"])

# %%
X = df.drop(df.columns[6], axis=1)
y = target

# %% [markdown]
# ### Separando aleatoriamente a base de treino (80% da base original) e a base de teste (20% da base original)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
def results_regression(y_test,y_pred):
    mse = mean_squared_error(y_test,y_pred)
    print(f"mse: {mse}")
    rmse = math.sqrt(mse)
    print(f"rmse: {rmse}")
    mae = mean_absolute_error(y_test,y_pred)
    print(f"mae: {mae}")
    mape = mean_absolute_percentage_error(y_test,y_pred)
    print(f"mape: {mape}")
    r2 = r2_score(y_test,y_pred)
    print(f"r2_score {r2}")

# %%
def computeRegressionDecisionTree(X_train, X_test, y_train, y_test,printResults):
    arvore_regressao = DecisionTreeRegressor()
    arvore_regressao.fit(X_train, y_train)
    y_pred = arvore_regressao.predict(X_test)
    if printResults:
        results_regression(y_test, y_pred)
    return y_pred, arvore_regressao

# %%
y_pred, arvore_regressao = computeRegressionDecisionTree(X_train, X_test, y_train, y_test, True)
# Out:
# mse: 546715.7274839669
# rmse: 739.4022771698549
# mae: 363.188772190724
# mape: 0.08539251249160656
# r2_score 0.9657970510878386

# %%
df = pd.DataFrame()
df['true'] = y_test
df['pred'] = y_pred
df
# Out:
#        true    pred
# 28297   432   414.0
# 17356  6964  6591.0
# 48882  2037  2005.0
# 19901  8451  7602.0
# 44377  1581  1813.0
# ...     ...     ...
# 42801  1351  1049.0
# 44262  1575  1699.0
# 5811   3911  4239.0
# 1858   3066  3690.0
# 44688  1611  1692.0
#
# [10759 rows x 2 columns]

# %%
df['diff'] = df['true'] - df['pred']
df
# Out:
#        true    pred   diff
# 28297   432   414.0   18.0
# 17356  6964  6591.0  373.0
# 48882  2037  2005.0   32.0
# 19901  8451  7602.0  849.0
# 44377  1581  1813.0 -232.0
# ...     ...     ...    ...
# 42801  1351  1049.0  302.0
# 44262  1575  1699.0 -124.0
# 5811   3911  4239.0 -328.0
# 1858   3066  3690.0 -624.0
# 44688  1611  1692.0  -81.0
#
# [10759 rows x 3 columns]

# %%
abs(df['diff']).sum()/len(df)
# Out:
# 363.188772190724
