# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, r2_score, DistanceMetric
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import neighbors
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Distância Euclidiana

# %% [markdown]
# ## Do princípio (from scratch)

# %%
def euclidean_distance(point1, point2):
    sum_squared_distance = 0
    for i in range(len(point1)):
        sum_squared_distance += math.pow(point1[i] - point2[i], 2)
    return math.sqrt(sum_squared_distance)

# %%
x = [2,5]
y = [3,4]

distance = euclidean_distance(x,y)

print(distance)
# Out:
# 1.4142135623730951

# %% [markdown]
# ## Usando numpy

# %% [markdown]
# ![Image](formula.jpg)

# %%
x = np.array((2,5))
y = np.array((3,4))

dist = np.linalg.norm(x - y) # Norma de uma matriz ou vetor

print(dist)
# Out:
# 1.4142135623730951

# %% [markdown]
# ## Usando sklearn

# %%
dist = DistanceMetric.get_metric('euclidean')
X = [[2, 5],
    [3, 4]]

print(dist.pairwise(X))
# Out:
# [[0.         1.41421356]
#  [1.41421356 0.        ]]

# %% [markdown]
# ![Image](distancias.jpg)

# %% [markdown]
# # Dados utilizados no KNN

# %% [markdown]
# # Classificação

# %% [markdown]
# # Carregando os dados

# %%
Train_Data = pd.read_csv("../../Datasets/heart.csv")
Train_Data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# ## Descrição das colunas

# %% [markdown]
# ### English
#
# 1. __Age__ is the age of candidate.
# 2. __Sex__ has numeric values. 1 denotes male and 0 denotes female.
# 3. __Chest Pain__ pain has values between 0-3. The types of angina that are described in the research paper. The higher the number, the lesser are the odds of heart attack.
# 4. __Resting blood pressure__ is normal pressure with no exercise.
# 5. __Cholesterol__ means the blockage for blood supply in the blood vessels.
# 6. __Fasting Blood Pressure__ is blood sugar taken after a long gap between a meal and the test. Typically, it's taken before any meal in the morning. 1 denotes > 120 mg/dl
# 7. __Rest ECG (electrocardiographic) results__ means ECG values taken while person is on rest which means no exercise and normal functioning of heart is happening. Values 0,1,2.
# 8. __The Maximum Heart Rate achieved__.
# 9. __Exercise induced angina__ is chest pain while exercising or doing any physical activity. 1 denotes presence and 0 denotes absence.
# 10. __Oldpeak__ = ST Depression induced by exercise relative to rest. ST Depression is the difference between value of ECG at rest and after exercise.
# 11. __ST Slope__ is the tangent to the depression value.
# 12. __The number of major blood vessels (0-3) supplying blood to heart blocked__.
# 13. __The Types of thalassemia__.
# 14. __Heart attack prediction__ where 1 denotes Heart attack occured and 0 where it din't take occur.
#
# ### Português
#
# 1. __Age__ é a idade do candidato.
# 2. __Sex__ possui valores numéricos. 1 denota masculino e 0 denota feminino.
# 3. A dor de __Dor no peito__ tem valores entre 0-3. Os tipos de angina descritos no artigo de pesquisa. Quanto maior o número, menores são as chances de ataque cardíaco.
# 4. __Pressão arterial em repouso__ é a pressão normal sem exercício.
# 5. __Colesterol__ significa o bloqueio do suprimento de sangue nos vasos sanguíneos.
# 6. __Pressão Arterial em Jejum__ é o nível de açúcar no sangue medido após um longo intervalo entre uma refeição e o teste. Normalmente, é tomado antes de qualquer refeição da manhã. 1 denota > 120 mg/dl
# 7. __Resultados de ECG (eletrocardiográfico) em repouso__ significa valores de ECG obtidos enquanto a pessoa está em repouso, o que significa que não há exercício e o funcionamento normal do coração está acontecendo. Valores 0,1,2.
# 8. __A frequência cardíaca máxima alcançada__.
# 9. __Angina induzida por exercício__ é uma dor no peito durante o exercício ou qualquer atividade física. 1 denota presença e 0 denota ausência.
# 10. __Oldpeak__ = Depressão ST induzida pelo exercício em relação ao repouso. A depressão do segmento ST é a diferença entre o valor do ECG em repouso e após o exercício.
# 11. __ST Slope__ é a tangente ao valor da depressão.
# 12. __O número dos principais vasos sanguíneos (0-3) que fornecem sangue ao coração estão bloqueados__.
# 13. __Os tipos de talassemia__.
# 14. __Previsão de ataque cardíaco__ onde 1 indica que ocorreu um ataque cardíaco e 0 onde não ocorreu.

# %%
Train_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# # Checar se as classes estão balanceadas

# %%
Train_Data['target'].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %% [markdown]
# # Checar se existem dados duplicados

# %%
print("Duplicated values: ", Train_Data.duplicated().sum())
duplicate = Train_Data[Train_Data.duplicated()]
duplicate
# Out:
# Duplicated values:  1
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 164   38    1   2       138   175    0        1      173      0      0.0
#
#      slope  ca  thal  target
# 164      2   4     2       1

# %% [markdown]
# ### Remover dados duplicados, deixando apenas a primeira ocorrência

# %%
Train_Data.drop_duplicates(keep='first',inplace=True) 
Train_Data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [302 rows x 14 columns]

# %% [markdown]
# # Checar se existem dados faltantes

# %%
print("Missing values: ", Train_Data.isnull().sum().sum())
# Out:
# Missing values:  0

# %% [markdown]
# # Checar se existem correlações entre os atributos e a saída

# %%
corr = Train_Data.corr()
corr.style.background_gradient(cmap = 'viridis')
# Out:
# <style type="text/css">
# #T_20277_row0_col0, #T_20277_row1_col1, #T_20277_row2_col2, #T_20277_row3_col3, #T_20277_row4_col4, #T_20277_row5_col5, #T_20277_row6_col6, #T_20277_row7_col7, #T_20277_row8_col8, #T_20277_row9_col9, #T_20277_row10_col10, #T_20277_row11_col11, #T_20277_row12_col12, #T_20277_row13_col13 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_20277_row0_col1 {
#   background-color: #46337f;
#   color: #f1f1f1;
# }
# #T_20277_row0_col2, #T_20277_row2_col0, #T_20277_row4_col3, #T_20277_row11_col4 {
#   background-color: #3d4e8a;
#   color: #f1f1f1;
# }
# #T_20277_row0_col3, #T_20277_row11_col12 {
#   background-color: #2c718e;
#   color: #f1f1f1;
# }
# #T_20277_row0_col4 {
#   background-color: #30698e;
#   color: #f1f1f1;
# }
# #T_20277_row0_col5, #T_20277_row7_col1, #T_20277_row7_col12, #T_20277_row8_col3 {
#   background-color: #423f85;
#   color: #f1f1f1;
# }
# #T_20277_row0_col6 {
#   background-color: #470d60;
#   color: #f1f1f1;
# }
# #T_20277_row0_col7, #T_20277_row1_col4, #T_20277_row4_col6, #T_20277_row6_col5, #T_20277_row7_col0, #T_20277_row8_col2, #T_20277_row8_col13, #T_20277_row9_col10, #T_20277_row10_col9, #T_20277_row13_col1, #T_20277_row13_col3, #T_20277_row13_col8, #T_20277_row13_col11, #T_20277_row13_col12 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_20277_row0_col8, #T_20277_row1_col11, #T_20277_row5_col0, #T_20277_row5_col9 {
#   background-color: #2d718e;
#   color: #f1f1f1;
# }
# #T_20277_row0_col9, #T_20277_row11_col0, #T_20277_row12_col9 {
#   background-color: #21908d;
#   color: #f1f1f1;
# }
# #T_20277_row0_col10 {
#   background-color: #3a548c;
#   color: #f1f1f1;
# }
# #T_20277_row0_col11 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_20277_row0_col12, #T_20277_row3_col12 {
#   background-color: #34608d;
#   color: #f1f1f1;
# }
# #T_20277_row0_col13, #T_20277_row2_col11, #T_20277_row7_col9 {
#   background-color: #463480;
#   color: #f1f1f1;
# }
# #T_20277_row1_col0, #T_20277_row8_col4, #T_20277_row12_col7 {
#   background-color: #3f4889;
#   color: #f1f1f1;
# }
# #T_20277_row1_col2, #T_20277_row12_col4 {
#   background-color: #3c508b;
#   color: #f1f1f1;
# }
# #T_20277_row1_col3, #T_20277_row1_col6 {
#   background-color: #481c6e;
#   color: #f1f1f1;
# }
# #T_20277_row1_col5, #T_20277_row11_col7, #T_20277_row12_col6 {
#   background-color: #472a7a;
#   color: #f1f1f1;
# }
# #T_20277_row1_col7, #T_20277_row3_col7, #T_20277_row4_col13, #T_20277_row6_col12, #T_20277_row13_col6 {
#   background-color: #3b518b;
#   color: #f1f1f1;
# }
# #T_20277_row1_col8, #T_20277_row12_col11 {
#   background-color: #29798e;
#   color: #f1f1f1;
# }
# #T_20277_row1_col9 {
#   background-color: #277f8e;
#   color: #f1f1f1;
# }
# #T_20277_row1_col10 {
#   background-color: #2f6b8e;
#   color: #f1f1f1;
# }
# #T_20277_row1_col12, #T_20277_row9_col12 {
#   background-color: #297b8e;
#   color: #f1f1f1;
# }
# #T_20277_row1_col13 {
#   background-color: #482677;
#   color: #f1f1f1;
# }
# #T_20277_row2_col1, #T_20277_row12_col3 {
#   background-color: #433e85;
#   color: #f1f1f1;
# }
# #T_20277_row2_col3 {
#   background-color: #443a83;
#   color: #f1f1f1;
# }
# #T_20277_row2_col4 {
#   background-color: #482576;
#   color: #f1f1f1;
# }
# #T_20277_row2_col5, #T_20277_row2_col6, #T_20277_row7_col6, #T_20277_row10_col0, #T_20277_row12_col2 {
#   background-color: #443983;
#   color: #f1f1f1;
# }
# #T_20277_row2_col7, #T_20277_row7_col2 {
#   background-color: #218f8d;
#   color: #f1f1f1;
# }
# #T_20277_row2_col8, #T_20277_row3_col6 {
#   background-color: #460b5e;
#   color: #f1f1f1;
# }
# #T_20277_row2_col9 {
#   background-color: #38588c;
#   color: #f1f1f1;
# }
# #T_20277_row2_col10 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_20277_row2_col12 {
#   background-color: #472f7d;
#   color: #f1f1f1;
# }
# #T_20277_row2_col13 {
#   background-color: #23a983;
#   color: #f1f1f1;
# }
# #T_20277_row3_col0 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_20277_row3_col1, #T_20277_row9_col2, #T_20277_row10_col12 {
#   background-color: #433d84;
#   color: #f1f1f1;
# }
# #T_20277_row3_col2, #T_20277_row6_col7 {
#   background-color: #33638d;
#   color: #f1f1f1;
# }
# #T_20277_row3_col4 {
#   background-color: #39568c;
#   color: #f1f1f1;
# }
# #T_20277_row3_col5 {
#   background-color: #3c4f8a;
#   color: #f1f1f1;
# }
# #T_20277_row3_col8, #T_20277_row4_col8, #T_20277_row5_col2, #T_20277_row8_col0 {
#   background-color: #2f6c8e;
#   color: #f1f1f1;
# }
# #T_20277_row3_col9 {
#   background-color: #218e8d;
#   color: #f1f1f1;
# }
# #T_20277_row3_col10 {
#   background-color: #365c8d;
#   color: #f1f1f1;
# }
# #T_20277_row3_col11 {
#   background-color: #2e6f8e;
#   color: #f1f1f1;
# }
# #T_20277_row3_col13 {
#   background-color: #414487;
#   color: #f1f1f1;
# }
# #T_20277_row4_col0, #T_20277_row9_col0 {
#   background-color: #27808e;
#   color: #f1f1f1;
# }
# #T_20277_row4_col1, #T_20277_row7_col5, #T_20277_row8_col6 {
#   background-color: #481a6c;
#   color: #f1f1f1;
# }
# #T_20277_row4_col2 {
#   background-color: #3e4c8a;
#   color: #f1f1f1;
# }
# #T_20277_row4_col5 {
#   background-color: #482071;
#   color: #f1f1f1;
# }
# #T_20277_row4_col7, #T_20277_row5_col7 {
#   background-color: #375a8c;
#   color: #f1f1f1;
# }
# #T_20277_row4_col9, #T_20277_row6_col13 {
#   background-color: #2a778e;
#   color: #f1f1f1;
# }
# #T_20277_row4_col10, #T_20277_row10_col2 {
#   background-color: #2d708e;
#   color: #f1f1f1;
# }
# #T_20277_row4_col11 {
#   background-color: #2e6d8e;
#   color: #f1f1f1;
# }
# #T_20277_row4_col12 {
#   background-color: #31668e;
#   color: #f1f1f1;
# }
# #T_20277_row5_col1, #T_20277_row6_col8 {
#   background-color: #3a538b;
#   color: #f1f1f1;
# }
# #T_20277_row5_col3, #T_20277_row5_col13 {
#   background-color: #375b8d;
#   color: #f1f1f1;
# }
# #T_20277_row5_col4, #T_20277_row6_col1 {
#   background-color: #443b84;
#   color: #f1f1f1;
# }
# #T_20277_row5_col6, #T_20277_row11_col6 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# #T_20277_row5_col8 {
#   background-color: #32658e;
#   color: #f1f1f1;
# }
# #T_20277_row5_col10, #T_20277_row6_col9, #T_20277_row12_col0 {
#   background-color: #31678e;
#   color: #f1f1f1;
# }
# #T_20277_row5_col11, #T_20277_row11_col8 {
#   background-color: #2a768e;
#   color: #f1f1f1;
# }
# #T_20277_row5_col12, #T_20277_row6_col11 {
#   background-color: #3d4d8a;
#   color: #f1f1f1;
# }
# #T_20277_row6_col0, #T_20277_row8_col10, #T_20277_row9_col4 {
#   background-color: #404588;
#   color: #f1f1f1;
# }
# #T_20277_row6_col2, #T_20277_row11_col1 {
#   background-color: #33628d;
#   color: #f1f1f1;
# }
# #T_20277_row6_col3 {
#   background-color: #460a5d;
#   color: #f1f1f1;
# }
# #T_20277_row6_col4, #T_20277_row7_col8 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_20277_row6_col10 {
#   background-color: #277e8e;
#   color: #f1f1f1;
# }
# #T_20277_row7_col3 {
#   background-color: #481f70;
#   color: #f1f1f1;
# }
# #T_20277_row7_col4 {
#   background-color: #453781;
#   color: #f1f1f1;
# }
# #T_20277_row7_col10 {
#   background-color: #25ab82;
#   color: #f1f1f1;
# }
# #T_20277_row7_col11, #T_20277_row10_col8 {
#   background-color: #472d7b;
#   color: #f1f1f1;
# }
# #T_20277_row7_col13 {
#   background-color: #22a785;
#   color: #f1f1f1;
# }
# #T_20277_row8_col1 {
#   background-color: #31688e;
#   color: #f1f1f1;
# }
# #T_20277_row8_col5 {
#   background-color: #482475;
#   color: #f1f1f1;
# }
# #T_20277_row8_col7 {
#   background-color: #450559;
#   color: #f1f1f1;
# }
# #T_20277_row8_col9 {
#   background-color: #1e9c89;
#   color: #f1f1f1;
# }
# #T_20277_row8_col11 {
#   background-color: #2c738e;
#   color: #f1f1f1;
# }
# #T_20277_row8_col12 {
#   background-color: #297a8e;
#   color: #f1f1f1;
# }
# #T_20277_row9_col1, #T_20277_row9_col3, #T_20277_row12_col10 {
#   background-color: #355f8d;
#   color: #f1f1f1;
# }
# #T_20277_row9_col5, #T_20277_row9_col6 {
#   background-color: #481d6f;
#   color: #f1f1f1;
# }
# #T_20277_row9_col7 {
#   background-color: #470e61;
#   color: #f1f1f1;
# }
# #T_20277_row9_col8 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_20277_row9_col11 {
#   background-color: #24868e;
#   color: #f1f1f1;
# }
# #T_20277_row9_col13 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_20277_row10_col1 {
#   background-color: #424186;
#   color: #f1f1f1;
# }
# #T_20277_row10_col3, #T_20277_row10_col5 {
#   background-color: #46085c;
#   color: #f1f1f1;
# }
# #T_20277_row10_col4 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
# #T_20277_row10_col6, #T_20277_row11_col5 {
#   background-color: #404688;
#   color: #f1f1f1;
# }

# %% [markdown]
# ## Dividir atributos e saída

# %%
X = np.array(Train_Data[Train_Data.columns[Train_Data.columns != 'target']])
y = np.array(Train_Data['target']).reshape(-1,1)
X[:5], y[:5]
# Out:
# (array([[ 63. ,   1. ,   3. , 145. , 233. ,   1. ,   0. , 150. ,   0. ,
#            2.3,   0. ,   0. ,   1. ],
#         [ 37. ,   1. ,   2. , 130. , 250. ,   0. ,   1. , 187. ,   0. ,
#            3.5,   0. ,   0. ,   2. ],
#         [ 41. ,   0. ,   1. , 130. , 204. ,   0. ,   0. , 172. ,   0. ,
#            1.4,   2. ,   0. ,   2. ],
#         [ 56. ,   1. ,   1. , 120. , 236. ,   0. ,   1. , 178. ,   0. ,
#            0.8,   2. ,   0. ,   2. ],
#         [ 57. ,   0. ,   0. , 120. , 354. ,   0. ,   1. , 163. ,   1. ,
#            0.6,   2. ,   0. ,   2. ]]),
#  array([[1],
#         [1],
#         [1],
#         [1],
#         [1]]))

# %% [markdown]
# # Separar treinamento e teste

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ## Resultados a serem imprimidos

# %%
def results(y_test,y_pred):
    results = confusion_matrix(y_test, y_pred)
    print ('Confusion Matrix :')
    print(results)
    accuracy = accuracy_score(y_test, y_pred)
    print("Accuracy: %.2f%%" % (accuracy * 100.0))
    print ('Report : ')
    print (classification_report(y_test, y_pred))

# %% [markdown]
# # KNN

# %%
def compute_knn(X_train, X_test, y_train, y_test, k_neighbors):

    neigh = KNeighborsClassifier(n_neighbors=k_neighbors, metric = 'euclidean', algorithm='auto')
    neigh.fit(X_train, np.array(y_train).flatten())
    y_pred = neigh.predict(X_test)
    results(y_test, y_pred)
    
    return y_pred

y_pred = compute_knn(X_train, X_test, y_train, y_test, 23)
# Out:
# Confusion Matrix :
# [[19  8]
#  [ 9 25]]
# Accuracy: 72.13%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.68      0.70      0.69        27
#            1       0.76      0.74      0.75        34
#
#     accuracy                           0.72        61
#    macro avg       0.72      0.72      0.72        61
# weighted avg       0.72      0.72      0.72        61

# %%
def error_plot(X_train, X_test, y_train, y_test, max = 40):

    error = []

    # Calculando o erro variando o k de 1 a 30
    for k in range(1, max, 2):
        pred_i = compute_knn(X_train, X_test, y_train, y_test, k)
        
        error.append(np.mean(pred_i != y_test))
        
    plt.figure(figsize=(12, 6))
    plt.plot(range(1, max, 2), error, color='red', linestyle='dashed', marker='o',
             markerfacecolor='blue', markersize=10)
    plt.title('Error Rate K Value')
    plt.xlabel('K Value')
    plt.ylabel('Mean Error')
    plt.show()

# %%
error_plot(X_train, X_test, y_train, y_test)
# Out:
# Confusion Matrix :
# [[15 12]
#  [13 21]]
# Accuracy: 59.02%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.54      0.56      0.55        27
#            1       0.64      0.62      0.63        34
#
#     accuracy                           0.59        61
#    macro avg       0.59      0.59      0.59        61
# weighted avg       0.59      0.59      0.59        61
#
# Confusion Matrix :
# [[13 14]
#  [12 22]]
# Accuracy: 57.38%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.52      0.48      0.50        27
#            1       0.61      0.65      0.63        34
#
#     accuracy                           0.57        61
#    macro avg       0.57      0.56      0.56        61
# weighted avg       0.57      0.57      0.57        61
#
# Confusion Matrix :
# [[12 15]
#  [10 24]]
# Accuracy: 59.02%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.55      0.44      0.49        27
#            1       0.62      0.71      0.66        34
#
#     accuracy                           0.59        61
#    macro avg       0.58      0.58      0.57        61
# weighted avg       0.58      0.59      0.58        61
#
# Confusion Matrix :
# [[15 12]
#  [11 23]]
# Accuracy: 62.30%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.58      0.56      0.57        27
#            1       0.66      0.68      0.67        34
#
#     accuracy                           0.62        61
#    macro avg       0.62      0.62      0.62        61
# weighted avg       0.62      0.62      0.62        61
#
# Confusion Matrix :
# [[15 12]
#  [ 9 25]]
# Accuracy: 65.57%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.62      0.56      0.59        27
#            1       0.68      0.74      0.70        34
#
#     accuracy                           0.66        61
#    macro avg       0.65      0.65      0.65        61
# weighted avg       0.65      0.66      0.65        61
#
# Confusion Matrix :
# [[18  9]
#  [10 24]]
# Accuracy: 68.85%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.64      0.67      0.65        27
#            1       0.73      0.71      0.72        34
#
#     accuracy                           0.69        61
#    macro avg       0.69      0.69      0.69        61
# weighted avg       0.69      0.69      0.69        61
#
# Confusion Matrix :
# [[18  9]
#  [10 24]]
# Accuracy: 68.85%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.64      0.67      0.65        27
#            1       0.73      0.71      0.72        34
#
#     accuracy                           0.69        61
#    macro avg       0.69      0.69      0.69        61
# weighted avg       0.69      0.69      0.69        61
#
# Confusion Matrix :
# [[17 10]
#  [10 24]]
# Accuracy: 67.21%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.63      0.63      0.63        27
#            1       0.71      0.71      0.71        34
#
#     accuracy                           0.67        61
#    macro avg       0.67      0.67      0.67        61
# weighted avg       0.67      0.67      0.67        61
#
# Confusion Matrix :
# [[17 10]
#  [10 24]]
# Accuracy: 67.21%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.63      0.63      0.63        27
#            1       0.71      0.71      0.71        34
#
#     accuracy                           0.67        61
#    macro avg       0.67      0.67      0.67        61
# weighted avg       0.67      0.67      0.67        61
#
# Confusion Matrix :
# [[18  9]
#  [10 24]]
# Accuracy: 68.85%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.64      0.67      0.65        27
#            1       0.73      0.71      0.72        34
#
#     accuracy                           0.69        61
#    macro avg       0.69      0.69      0.69        61
# weighted avg       0.69      0.69      0.69        61
#
# Confusion Matrix :
# [[17 10]
#  [10 24]]
# Accuracy: 67.21%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.63      0.63      0.63        27
#            1       0.71      0.71      0.71        34
#
#     accuracy                           0.67        61
#    macro avg       0.67      0.67      0.67        61
# weighted avg       0.67      0.67      0.67        61
#
# Confusion Matrix :
# [[19  8]
#  [ 9 25]]
# Accuracy: 72.13%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.68      0.70      0.69        27
#            1       0.76      0.74      0.75        34
#
#     accuracy                           0.72        61
#    macro avg       0.72      0.72      0.72        61
# weighted avg       0.72      0.72      0.72        61
#
# Confusion Matrix :
# [[17 10]
#  [ 8 26]]
# Accuracy: 70.49%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.68      0.63      0.65        27
#            1       0.72      0.76      0.74        34
#
#     accuracy                           0.70        61
#    macro avg       0.70      0.70      0.70        61
# weighted avg       0.70      0.70      0.70        61
#
# Confusion Matrix :
# [[17 10]
#  [ 8 26]]
# Accuracy: 70.49%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.68      0.63      0.65        27
#            1       0.72      0.76      0.74        34
#
#     accuracy                           0.70        61
#    macro avg       0.70      0.70      0.70        61
# weighted avg       0.70      0.70      0.70        61
#
# Confusion Matrix :
# [[17 10]
#  [ 8 26]]
# Accuracy: 70.49%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.68      0.63      0.65        27
#            1       0.72      0.76      0.74        34
#
#     accuracy                           0.70        61
#    macro avg       0.70      0.70      0.70        61
# weighted avg       0.70      0.70      0.70        61
#
# Confusion Matrix :
# [[17 10]
#  [ 7 27]]
# Accuracy: 72.13%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.71      0.63      0.67        27
#            1       0.73      0.79      0.76        34
#
#     accuracy                           0.72        61
#    macro avg       0.72      0.71      0.71        61
# weighted avg       0.72      0.72      0.72        61
#
# Confusion Matrix :
# [[15 12]
#  [ 7 27]]
# Accuracy: 68.85%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.68      0.56      0.61        27
#            1       0.69      0.79      0.74        34
#
#     accuracy                           0.69        61
#    macro avg       0.69      0.67      0.68        61
# weighted avg       0.69      0.69      0.68        61
#
# Confusion Matrix :
# [[14 13]
#  [ 6 28]]
# Accuracy: 68.85%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.70      0.52      0.60        27
#            1       0.68      0.82      0.75        34
#
#     accuracy                           0.69        61
#    macro avg       0.69      0.67      0.67        61
# weighted avg       0.69      0.69      0.68        61
#
# Confusion Matrix :
# [[14 13]
#  [ 6 28]]
# Accuracy: 68.85%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.70      0.52      0.60        27
#            1       0.68      0.82      0.75        34
#
#     accuracy                           0.69        61
#    macro avg       0.69      0.67      0.67        61
# weighted avg       0.69      0.69      0.68        61
#
# Confusion Matrix :
# [[14 13]
#  [ 5 29]]
# Accuracy: 70.49%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.74      0.52      0.61        27
#            1       0.69      0.85      0.76        34
#
#     accuracy                           0.70        61
#    macro avg       0.71      0.69      0.69        61
# weighted avg       0.71      0.70      0.69        61

# %% [markdown]
# # KNN com dados normalizados

# %%
def compute_knn_normalized(X_train, X_test, y_train, y_test, k_neighbors):

    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)

    neigh = KNeighborsClassifier(n_neighbors=k_neighbors, metric = 'euclidean', algorithm='auto')
    neigh.fit(X_train, y_train)
    y_pred = neigh.predict(X_test)

    results(y_test, y_pred)
    return y_pred

# %%
y_pred = compute_knn_normalized(X_train, X_test, y_train, y_test, 3)
# Out:
# Confusion Matrix :
# [[26  1]
#  [ 4 30]]
# Accuracy: 91.80%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91        27
#            1       0.97      0.88      0.92        34
#
#     accuracy                           0.92        61
#    macro avg       0.92      0.92      0.92        61
# weighted avg       0.92      0.92      0.92        61
# /home/pablo_veinberg/.local/lib/python3.10/site-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %% [markdown]
# ## Plotando gráfico de erro

# %%
def error_plot(X_train, X_test, y_train, y_test):

    error = []

    # Calculando o erro variando o k de 1 a 30
    for k in range(1, 30, 2):
        pred_i = compute_knn_normalized(X_train, X_test, y_train, y_test, k)
        
        error.append(np.mean(pred_i != y_test))
        
    plt.figure(figsize=(12, 6))
    plt.plot(range(1, 30, 2), error, color='red', linestyle='dashed', marker='o',
             markerfacecolor='blue', markersize=10)
    plt.title('Error Rate K Value')
    plt.xlabel('K Value')
    plt.ylabel('Mean Error')
    plt.show()

# %%
error_plot(X_train, X_test, y_train, y_test)
# Out:
# /home/pablo_veinberg/.local/lib/python3.10/site-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/pablo_veinberg/.local/lib/python3.10/site-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/pablo_veinberg/.local/lib/python3.10/site-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/pablo_veinberg/.local/lib/python3.10/site-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/pablo_veinberg/.local/lib/python3.10/site-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/pablo_veinberg/.local/lib/python3.10/site-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/pablo_veinberg/.local/lib/python3.10/site-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/pablo_veinberg/.local/lib/python3.10/site-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/pablo_veinberg/.local/lib/python3.10/site-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/pablo_veinberg/.local/lib/python3.10/site-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/pablo_veinberg/.local/lib/python3.10/site-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/pablo_veinberg/.local/lib/python3.10/site-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/pablo_veinberg/.local/lib/python3.10/site-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/pablo_veinberg/.local/lib/python3.10/site-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /home/pablo_veinberg/.local/lib/python3.10/site-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Confusion Matrix :
# [[24  3]
#  [ 6 28]]
# Accuracy: 85.25%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.80      0.89      0.84        27
#            1       0.90      0.82      0.86        34
#
#     accuracy                           0.85        61
#    macro avg       0.85      0.86      0.85        61
# weighted avg       0.86      0.85      0.85        61
#
# Confusion Matrix :
# [[26  1]
#  [ 4 30]]
# Accuracy: 91.80%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91        27
#            1       0.97      0.88      0.92        34
#
#     accuracy                           0.92        61
#    macro avg       0.92      0.92      0.92        61
# weighted avg       0.92      0.92      0.92        61
#
# Confusion Matrix :
# [[25  2]
#  [ 3 31]]
# Accuracy: 91.80%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91        27
#            1       0.94      0.91      0.93        34
#
#     accuracy                           0.92        61
#    macro avg       0.92      0.92      0.92        61
# weighted avg       0.92      0.92      0.92        61
#
# Confusion Matrix :
# [[25  2]
#  [ 3 31]]
# Accuracy: 91.80%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91        27
#            1       0.94      0.91      0.93        34
#
#     accuracy                           0.92        61
#    macro avg       0.92      0.92      0.92        61
# weighted avg       0.92      0.92      0.92        61
#
# Confusion Matrix :
# [[24  3]
#  [ 3 31]]
# Accuracy: 90.16%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89        27
#            1       0.91      0.91      0.91        34
#
#     accuracy                           0.90        61
#    macro avg       0.90      0.90      0.90        61
# weighted avg       0.90      0.90      0.90        61
#
# Confusion Matrix :
# [[23  4]
#  [ 4 30]]
# Accuracy: 86.89%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85        27
#            1       0.88      0.88      0.88        34
#
#     accuracy                           0.87        61
#    macro avg       0.87      0.87      0.87        61
# weighted avg       0.87      0.87      0.87        61
#
# Confusion Matrix :
# [[23  4]
#  [ 2 32]]
# Accuracy: 90.16%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.92      0.85      0.88        27
#            1       0.89      0.94      0.91        34
#
#     accuracy                           0.90        61
#    macro avg       0.90      0.90      0.90        61
# weighted avg       0.90      0.90      0.90        61
#
# Confusion Matrix :
# [[23  4]
#  [ 2 32]]
# Accuracy: 90.16%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.92      0.85      0.88        27
#            1       0.89      0.94      0.91        34
#
#     accuracy                           0.90        61
#    macro avg       0.90      0.90      0.90        61
# weighted avg       0.90      0.90      0.90        61
#
# Confusion Matrix :
# [[22  5]
#  [ 2 32]]
# Accuracy: 88.52%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.92      0.81      0.86        27
#            1       0.86      0.94      0.90        34
#
#     accuracy                           0.89        61
#    macro avg       0.89      0.88      0.88        61
# weighted avg       0.89      0.89      0.88        61
#
# Confusion Matrix :
# [[22  5]
#  [ 2 32]]
# Accuracy: 88.52%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.92      0.81      0.86        27
#            1       0.86      0.94      0.90        34
#
#     accuracy                           0.89        61
#    macro avg       0.89      0.88      0.88        61
# weighted avg       0.89      0.89      0.88        61
#
# Confusion Matrix :
# [[22  5]
#  [ 2 32]]
# Accuracy: 88.52%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.92      0.81      0.86        27
#            1       0.86      0.94      0.90        34
#
#     accuracy                           0.89        61
#    macro avg       0.89      0.88      0.88        61
# weighted avg       0.89      0.89      0.88        61
#
# Confusion Matrix :
# [[22  5]
#  [ 2 32]]
# Accuracy: 88.52%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.92      0.81      0.86        27
#            1       0.86      0.94      0.90        34
#
#     accuracy                           0.89        61
#    macro avg       0.89      0.88      0.88        61
# weighted avg       0.89      0.89      0.88        61
#
# Confusion Matrix :
# [[22  5]
#  [ 2 32]]
# Accuracy: 88.52%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.92      0.81      0.86        27
#            1       0.86      0.94      0.90        34
#
#     accuracy                           0.89        61
#    macro avg       0.89      0.88      0.88        61
# weighted avg       0.89      0.89      0.88        61
#
# Confusion Matrix :
# [[22  5]
#  [ 2 32]]
# Accuracy: 88.52%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.92      0.81      0.86        27
#            1       0.86      0.94      0.90        34
#
#     accuracy                           0.89        61
#    macro avg       0.89      0.88      0.88        61
# weighted avg       0.89      0.89      0.88        61
#
# Confusion Matrix :
# [[22  5]
#  [ 2 32]]
# Accuracy: 88.52%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.92      0.81      0.86        27
#            1       0.86      0.94      0.90        34
#
#     accuracy                           0.89        61
#    macro avg       0.89      0.88      0.88        61
# weighted avg       0.89      0.89      0.88        61

# %% [markdown]
# # Regressão

# %%
df = pd.read_csv('../../Datasets/diamonds.csv', sep = ",", low_memory=False)
#removendo os ids
df = df.drop(df.columns[0], axis=1)
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# ### Dicionário de dados
#
# **price**: price in US dollars (\$326--\$18,823)
#
# **carat**: weight of the diamond (0.2--5.01)
#
# **cut**: quality of the cut (Fair, Good, Very Good, Premium, Ideal)
#
# **color**: diamond colour, from J (worst) to D (best)
#
# **clarity**: a measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
#
# **x**: length in mm (0--10.74)
#
# **y**: width in mm (0--58.9)
#
# **z**: depth in mm (0--31.8)
#
# **depth**: total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79)
#
# **table**: width of top of diamond relative to widest point (43--95)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %% [markdown]
# ## One Hot Encoding
#
# Transformar atributos nominais em numéricos

# %%
le = LabelEncoder()
for column in df.columns:
    if(df[column].dtypes=='object'):
        df[column] = le.fit_transform(df[column])
        
df.head()
# Out:
#    carat  cut  color  clarity  depth  table  price     x     y     z
# 0   0.23    2      1        3   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    3      1        2   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23    1      1        4   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    3      5        5   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31    1      6        3   63.3   58.0    335  4.34  4.35  2.75

# %%
print("Missing values: ", df.isnull().sum())
# Out:
# Missing values:  carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %% [markdown]
# ### Checando se existem dados duplicados, preservando a primeira ocorrência:

# %%
print("Duplicated values: ", df.duplicated().sum())

#Checando quais são as linhas duplicadas
duplicateRowsDF = df[df.duplicated()]
#duplicateRowsDF

#Removendo as linhas duplicadas, deixando apenas a primeira ocorrência
df.drop_duplicates(keep='first',inplace=True) 
#df
# Out:
# Duplicated values:  146

# %%
corr = df.corr()
corr.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_4b51c_row0_col0, #T_4b51c_row1_col1, #T_4b51c_row2_col2, #T_4b51c_row3_col3, #T_4b51c_row4_col4, #T_4b51c_row5_col5, #T_4b51c_row6_col6, #T_4b51c_row7_col7, #T_4b51c_row8_col8, #T_4b51c_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_4b51c_row0_col1 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_4b51c_row0_col2 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_4b51c_row0_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_4b51c_row0_col4 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_4b51c_row0_col5, #T_4b51c_row8_col5 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_4b51c_row0_col6 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_4b51c_row0_col7, #T_4b51c_row7_col0, #T_4b51c_row7_col8, #T_4b51c_row8_col7 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_4b51c_row0_col8, #T_4b51c_row8_col0, #T_4b51c_row8_col9, #T_4b51c_row9_col8 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_4b51c_row0_col9, #T_4b51c_row9_col0 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_4b51c_row1_col0, #T_4b51c_row3_col4 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_4b51c_row1_col2 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_4b51c_row1_col3, #T_4b51c_row8_col4 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_4b51c_row1_col4 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_4b51c_row1_col5, #T_4b51c_row9_col5 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_4b51c_row1_col6 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_4b51c_row1_col7, #T_4b51c_row1_col8, #T_4b51c_row4_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_4b51c_row1_col9, #T_4b51c_row3_col1, #T_4b51c_row5_col6, #T_4b51c_row8_col1 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_4b51c_row2_col0 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_4b51c_row2_col1, #T_4b51c_row2_col3, #T_4b51c_row3_col5, #T_4b51c_row4_col7, #T_4b51c_row9_col1 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_4b51c_row2_col4 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_4b51c_row2_col5 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_4b51c_row2_col6 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_4b51c_row2_col7 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_4b51c_row2_col8 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_4b51c_row2_col9 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_4b51c_row3_col0, #T_4b51c_row3_col2, #T_4b51c_row3_col6, #T_4b51c_row3_col7, #T_4b51c_row3_col8, #T_4b51c_row3_col9, #T_4b51c_row4_col1, #T_4b51c_row4_col5, #T_4b51c_row5_col4, #T_4b51c_row7_col3, #T_4b51c_row9_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_4b51c_row4_col2 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_4b51c_row4_col3 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_4b51c_row4_col6 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_4b51c_row4_col8 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_4b51c_row4_col9 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_4b51c_row5_col0, #T_4b51c_row6_col5 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_4b51c_row5_col1, #T_4b51c_row9_col2 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_4b51c_row5_col2 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_4b51c_row5_col3 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_4b51c_row5_col7 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_4b51c_row5_col8 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_4b51c_row5_col9 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_4b51c_row6_col0 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_4b51c_row6_col1 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_4b51c_row6_col2 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_4b51c_row6_col3 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_4b51c_row6_col4 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_4b51c_row6_col7 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_4b51c_row6_col8 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_4b51c_row6_col9 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_4b51c_row7_col1 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_4b51c_row7_col2 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_4b51c_row7_col4 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_4b51c_row7_col5 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_4b51c_row7_col6 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_4b51c_row7_col9, #T_4b51c_row9_col7 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_4b51c_row8_col2 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_4b51c_row8_col3 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_4b51c_row8_col6 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_4b51c_row9_col4 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_4b51c_row9_col6 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4b51c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b51c_level0_col0" class="col_heading level0 col0" >carat</th>
#       <th id="T_4b51c_level0_col1" class="col_heading level0 col1" >cut</th>
#       <th id="T_4b51c_level0_col2" class="col_heading level0 col2" >color</th>
#       <th id="T_4b51c_level0_col3" class="col_heading level0 col3" >clarity</th>
#       <th id="T_4b51c_level0_col4" class="col_heading level0 col4" >depth</th>
#       <th id="T_4b51c_level0_col5" class="col_heading level0 col5" >table</th>
#       <th id="T_4b51c_level0_col6" class="col_heading level0 col6" >price</th>
#       <th id="T_4b51c_level0_col7" class="col_heading level0 col7" >x</th>
#       <th id="T_4b51c_level0_col8" class="col_heading level0 col8" >y</th>
#       <th id="T_4b51c_level0_col9" class="col_heading level0 col9" >z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b51c_level0_row0" class="row_heading level0 row0" >carat</th>
#       <td id="T_4b51c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_4b51c_row0_col1" class="data row0 col1" >0.017785</td>
#       <td id="T_4b51c_row0_col2" class="data row0 col2" >0.291019</td>
#       <td id="T_4b51c_row0_col3" class="data row0 col3" >-0.214068</td>
#       <td id="T_4b51c_row0_col4" class="data row0 col4" >0.027861</td>
#       <td id="T_4b51c_row0_col5" class="data row0 col5" >0.181091</td>
#       <td id="T_4b51c_row0_col6" class="data row0 col6" >0.921548</td>
#       <td id="T_4b51c_row0_col7" class="data row0 col7" >0.975380</td>
#       <td id="T_4b51c_row0_col8" class="data row0 col8" >0.951908</td>
#       <td id="T_4b51c_row0_col9" class="data row0 col9" >0.953542</td>
#     </tr>
#     <tr>
#       <th id="T_4b51c_level0_row1" class="row_heading level0 row1" >cut</th>
#       <td id="T_4b51c_row1_col0" class="data row1 col0" >0.017785</td>
#       <td id="T_4b51c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_4b51c_row1_col2" class="data row1 col2" >0.000393</td>
#       <td id="T_4b51c_row1_col3" class="data row1 col3" >0.028141</td>
#       <td id="T_4b51c_row1_col4" class="data row1 col4" >-0.193184</td>
#       <td id="T_4b51c_row1_col5" class="data row1 col5" >0.150366</td>
#       <td id="T_4b51c_row1_col6" class="data row1 col6" >0.040196</td>
#       <td id="T_4b51c_row1_col7" class="data row1 col7" >0.022592</td>
#       <td id="T_4b51c_row1_col8" class="data row1 col8" >0.027805</td>
#       <td id="T_4b51c_row1_col9" class="data row1 col9" >0.002442</td>
#     </tr>
#     <tr>
#       <th id="T_4b51c_level0_row2" class="row_heading level0 row2" >color</th>
#       <td id="T_4b51c_row2_col0" class="data row2 col0" >0.291019</td>
#       <td id="T_4b51c_row2_col1" class="data row2 col1" >0.000393</td>
#       <td id="T_4b51c_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_4b51c_row2_col3" class="data row2 col3" >-0.028002</td>
#       <td id="T_4b51c_row2_col4" class="data row2 col4" >0.047572</td>
#       <td id="T_4b51c_row2_col5" class="data row2 col5" >0.026102</td>
#       <td id="T_4b51c_row2_col6" class="dat

# %% [markdown]
# ### Separando o alvo (preço) dos atributos

# %%
target = pd.DataFrame(df, columns=["price"])

# %%
X = df.drop(df.columns[6], axis=1)
y = target

# %% [markdown]
# ### Separando aleatoriamente a base de treino (80% da base original) e a base de teste (20% da base original)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ## Regressão baseada no k-nearest neighbors:

# %% [markdown]
# Testando com distribuição uniforme e distância euclidiana:

# %%
def knn_regression(n_neighbors, distance_metric, optimizer):
    
    knn = neighbors.KNeighborsRegressor(n_neighbors = n_neighbors, metric = distance_metric, algorithm=optimizer)
    model_KNN = knn.fit(X_train, y_train)
    y_pred = model_KNN.predict(X_test)

    print("<----- " + str(knn.weights) + " knn.score = R2 score ----->")
    r2 = knn.score(X_test,y_test) * 100
    print(str(r2) + "\n")

    print("<----- " + str(knn.weights) + " método R2 score ----->")
    print(str(r2_score(y_test, y_pred) * 100) + "\n")

# %%
knn_regression(3,'euclidean', 'auto')
# Out:
# <----- uniform knn.score = R2 score ----->
# 94.51609220950677
#
# <----- uniform método R2 score ----->
# 94.51609220950677
